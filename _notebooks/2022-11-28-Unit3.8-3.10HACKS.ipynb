# %% [markdown]
# # Unit 3.8-3.10 HACKS
# > Review tickets for Unit 3 Sections 8 and 10
#
# - title: Unit 3 Sections 8 and 10 HACKS
# - toc: true
# - comments: true
# - categories: [unit 3]

# %% [markdown]
# ## Unit 3 Section 8

# %% [markdown]
# > Section 8 HACKS

# %% [markdown]
# ### Unit 3 Section 8.1

# %% [markdown]
# ### Unit 3 Section 8.2

# %% [markdown]
# ### Unit 3 Section 8.3

# %% [markdown]
# ## Unit 3 Section 10

# %% [markdown]
# > Section 10 HACKS
